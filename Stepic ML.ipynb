# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
students_perfomance = pd.read_csv("D://DataSC//Datasets//StudentsPerformance.csv")
students_perfomance = students_perfomance\
    .rename(columns={"math score": "math_score", "reading score": "reading_score", "writing score": "writing_score"})
students_perfomance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students_perfomance.plot.scatter(x="math_score", y ="reading_score")

# %%
graphic = sns.lmplot(x="math_score", y ="reading_score", hue="gender", data=students_perfomance)
graphic.set_xlabels("Math")
graphic.set_ylabels("Reading")

# %%
students_perfomance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df = pd.read_csv("https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv", sep=",")
df.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
df['roles_count_len']= df.roles.map(lambda x : len(x.split(",")))
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles  role_count  \
# 0                       ['Carry', 'Escape', 'Nuker']           3
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']           4
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']           4
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...           5
# ...

# %%
df2 = df.drop(columns=["role_count_2", "role_count", "role_count_3"])
df2
# Out:
#      Unnamed: 0 attack_type   id  legs       localized_name  \
# 0             0       Melee    1     2            Anti-Mage
# 1             1       Melee    2     2                  Axe
# 2             2      Ranged    3     4                 Bane
# 3             3       Melee    4     2          Bloodseeker
# 4             4      Ranged    5     2       Crystal Maiden
# 5             5      Ranged    6     2          Drow Ranger
# 6             6       Melee    7     2          Earthshaker
# 7             7       Melee    8     2           Juggernaut
# 8             8      Ranged    9     2               Mirana
# 9             9      Ranged   10     0            Morphling
# 10           10      Ranged   11     0         Shadow Fiend
# 11           11       Melee   12     2       Phantom Lancer
# 12           12      Ranged   13     2                 Puck
# 13           13       Melee   14     2                Pudge
# 14           14      Ranged   15     0                Razor
# ...

# %%
df2.plot.scatter(x="id", y="roles_count_len")

# %%
students_perfomance.iloc[0:3, 0:5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none

# %%
students_perfomance.iloc[[0,3,5], [1,2,-1]]
# Out:
#   race/ethnicity parental level of education  writing score
# 0        group B           bachelor's degree             74
# 3        group A          associate's degree             44
# 5        group B          associate's degree             78

# %%
students_perfomance.filter(like="score").head()
# Out:
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
df = pd.read_csv("https://stepik.org/media/attachments/course/4852/titanic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
df2 = students_perfomance.iloc[[0,3,4,6,8]]

# %%
df2
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 6  female        group B                some college      standard
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 6               completed          88             95             92
# 8               completed          64             64             67

# %%
df2.index = ["kupchanski", "Vasya", "jayz","dfa", "2fs"]

# %%
df2
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# kupchanski  female        group B           bachelor's degree      standard
# Vasya         male        group A          associate's degree  free/reduced
# jayz          male        group C                some college      standard
# dfa         female        group B                some college      standard
# 2fs           male        group D                 high school  free/reduced
#
#            test preparation course  math score  reading score  writing score
# kupchanski                    none          72             72             74
# Vasya                         none          47             57             44
# jayz                          none          76             78             75
# dfa                      completed          88             95             92
# 2fs                      completed          64             64             67

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
df2[df2["gender"]=="female"]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 6               completed          88             95             92

# %%
students_perfomance.groupby("gender")\
            .aggregate({"math_score":"mean", "reading_score":"mean"})\
            .rename(columns = {"math_score": "mean_math_score"})
# Out:
#         mean_math_score  reading_score
# gender
# female        63.633205      72.608108
# male          68.728216      65.473029

# %%
dota_frame = pd.read_csv("https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv")
dota_frame.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota_frame = dota_frame.drop("Unnamed: 0", axis=1)

# %%
dota_frame.groupby("legs").count()
# Out:
#       attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0              11  11              11    11            11     11
# 2              95  95              95    95            95     95
# 4               7   7               7     7             7      7
# 6               3   3               3     3             3      3
# 8               1   1               1     1             1      1

# %%
df = pd.read_csv("https://stepik.org/media/attachments/course/4852/accountancy.csv")
df.head()
df.groupby( ["Executor","Type"]).mean()
# Out:
#                Unnamed: 0      Salary
# Executor Type
# Loopa    A      46.000000   58.000000
#          B      24.000000  145.166667
#          C      31.666667  154.333333
#          D      31.857143  137.714286
#          E      23.500000  164.000000
#          F      20.000000  238.000000
# Pupa     A      16.000000  160.833333
#          B      41.000000   77.000000
#          C      23.000000   74.500000
#          D      14.000000  146.500000
#          E      19.800000  131.200000
#          F      25.750000  136.250000

# %%
df = pd.read_csv("http://stepik.org/media/attachments/course/4852/algae.csv")

# %%
df[df["genus"] == "Fucus"].describe()
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# count  3.000000  3.000000  3.000000  3.000000    3.000000
# mean   4.355112  3.566411  4.214878  2.814803    3.367647
# std    2.110570  3.149943  2.691679  0.713559    3.050376
# min    3.001472  0.346431  1.216767  2.272724    0.304573
# 25%    3.139171  2.028965  3.110515  2.410591    1.848888
# 50%    3.276870  3.711498  5.004262  2.548459    3.393203
# 75%    5.031933  5.176401  5.713934  3.085842    4.899184
# max    6.786996  6.641303  6.423606  3.623225    6.405165

# %%
df.groupby("group").describe()
# Out:
#       sucrose                                                             \
#         count      mean       std       min       25%      50%       75%
# group
# brown     6.0  4.709666  2.336471  1.636122  3.070321  5.00397  6.773014
# green     3.0  4.008792  1.634817  2.452623  3.157047  3.86147  4.786877
# red       1.0  0.704580       NaN  0.704580  0.704580  0.70458  0.704580
#
#                 alanin            ...   glucose           oleic_acid  \
#             max  count      mean  ...       75%       max      count
# group                             ...
# brown  6.825467    6.0  3.103846  ...  3.866782  6.013219        6.0
# green  5.712284    3.0  3.997055  ...  3.041936  3.343707        3.0
# red    0.704580    1.0  3.176440  ...  3.242090  3.242090        1.0
#
#
#            mean       std       min       25%       50%       75%       max
# group
# brown  3.584995  2.094095  0.304573  2.672695  3.774952  4.652528  6.405165
# ...
